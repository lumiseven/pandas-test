# %% [markdown]
# # 检测 pandas 版本

# %%
import pandas as pd 
pd.__version__
# Out:
# '1.4.3'

# %%
# ```bash
# pip list | grep -i pandas
# ```

# %% [markdown]
# # 获取测试数据集
# https://www.gairuo.com/file/data/dataset/team.xlsx
# 并且将数据下载到与当前 notebook 同一级目录

# %%
import pandas as pd
df = pd.read_excel('team.xlsx')
df
# 由于数据量大 仅展示前后5条数据
# Out:
#         name team  Q1  Q2  Q3  Q4
# 0      Liver    E  89  21  24  64
# 1       Arry    C  36  37  37  57
# 2        Ack    A  57  60  18  84
# 3      Eorge    C  93  96  71  78
# 4        Oah    D  65  49  61  86
# ..       ...  ...  ..  ..  ..  ..
# 95   Gabriel    C  48  59  87  74
# 96   Austin7    C  21  31  30  43
# 97  Lincoln4    C  98  93   1  20
# 98       Eli    E  11  74  58  91
# 99       Ben    E  21  43  41  74
#
# [100 rows x 6 columns]

# %%
df.dtypes
# Out:
# name    object
# team    object
# Q1       int64
# Q2       int64
# Q3       int64
# Q4       int64
# dtype: object

# %%
df.team.dtype
df.team.dtypes
# Out:
# dtype('O')

# %%
# 前5条a
df.head()
# Out:
#     name team  Q1  Q2  Q3  Q4
# 0  Liver    E  89  21  24  64
# 1   Arry    C  36  37  37  57
# 2    Ack    A  57  60  18  84
# 3  Eorge    C  93  96  71  78
# 4    Oah    D  65  49  61  86

# %%
# 后5条
df.tail()
# Out:
#         name team  Q1  Q2  Q3  Q4
# 95   Gabriel    C  48  59  87  74
# 96   Austin7    C  21  31  30  43
# 97  Lincoln4    C  98  93   1  20
# 98       Eli    E  11  74  58  91
# 99       Ben    E  21  43  41  74

# %%
# 随机查看5条
df.sample(5)
# Out:
#        name team  Q1  Q2  Q3  Q4
# 0     Liver    E  89  21  24  64
# 96  Austin7    C  21  31  30  43
# 65   Reuben    D  70  72  76  56
# 34  Reggie1    A  30  12  23   9
# 78  Elliott    B   9  31  33  60

# %%
# 校验数据加载是否完全
# 查看总行数和列数
df.shape
# Out:
# (100, 6)

# %%
# 查看索引 数据类型 内存信息
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    100 non-null    object
#  1   team    100 non-null    object
#  2   Q1      100 non-null    int64
#  3   Q2      100 non-null    int64
#  4   Q3      100 non-null    int64
#  5   Q4      100 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 4.8+ KB

# %%
# 查看各个字段数据类型
df.dtypes
# Out:
# name    object
# team    object
# Q1       int64
# Q2       int64
# Q3       int64
# Q4       int64
# dtype: object

# %%
# 显示数据行和列名
df.axes
# Out:
# [RangeIndex(start=0, stop=100, step=1),
#  Index(['name', 'team', 'Q1', 'Q2', 'Q3', 'Q4'], dtype='object')]

# %%
# 显示列名
df.columns
# Out:
# Index(['team', 'Q1', 'Q2', 'Q3', 'Q4'], dtype='object')

# %%
df.

# %%
# 计算 总数(count) 平均数(mean) 标准差(std) 最小值(min) 4分位数 最大值(max)
df.describe()
# Out:
#                Q1          Q2          Q3          Q4
# count  100.000000  100.000000  100.000000  100.000000
# mean    49.200000   52.550000   52.670000   52.780000
# std     29.962603   29.845181   26.543677   27.818524
# min      1.000000    1.000000    1.000000    2.000000
# 25%     19.500000   26.750000   29.500000   29.500000
# 50%     51.500000   49.500000   55.000000   53.000000
# 75%     74.250000   77.750000   76.250000   75.250000
# max     98.000000   99.000000   99.000000   99.000000

# %%
# 设置所以字段 name
df.set_index('name', inplace=True)

# %%
df.head()
# Out:
#       team  Q1  Q2  Q3  Q4
# name
# Liver    E  89  21  24  64
# Arry     C  36  37  37  57
# Ack      A  57  60  18  84
# Eorge    C  93  96  71  78
# Oah      D  65  49  61  86

# %% [markdown]
# # 数据选取

# %%
# 查看指定列
df['Q1']
# Out:
# name
# Liver       89
# Arry        36
# Ack         57
# Eorge       93
# Oah         65
#             ..
# Gabriel     48
# Austin7     21
# Lincoln4    98
# Eli         11
# Ben         21
# Name: Q1, Length: 100, dtype: int64

# %%
df.Q1
# Out:
# name
# Liver       89
# Arry        36
# Ack         57
# Eorge       93
# Oah         65
#             ..
# Gabriel     48
# Austin7     21
# Lincoln4    98
# Eli         11
# Ben         21
# Name: Q1, Length: 100, dtype: int64

# %%
# 选择多个列
df[['Q1','Q2']]
# Out:
#           Q1  Q2
# name
# Liver     89  21
# Arry      36  37
# Ack       57  60
# Eorge     93  96
# Oah       65  49
# ...       ..  ..
# Gabriel   48  59
# Austin7   21  31
# Lincoln4  98  93
# Eli       11  74
# Ben       21  43
#
# [100 rows x 2 columns]

# %%
# 使用 df.loc[x, y]
df.loc[:, ['team', 'Q2']]
# Out:
#          team  Q2
# name
# Liver       E  21
# Arry        C  37
# Ack         A  60
# Eorge       C  96
# Oah         D  49
# ...       ...  ..
# Gabriel     C  59
# Austin7     C  31
# Lincoln4    C  93
# Eli         E  74
# Ben         E  43
#
# [100 rows x 2 columns]

# %%
# 选择行
df[df.index == 'Liver']
# Out:
#       team  Q1  Q2  Q3  Q4
# name
# Liver    E  89  21  24  64

# %%
# 取前3行
df[0:3]
# Out:
#       team  Q1  Q2  Q3  Q4
# name
# Liver    E  89  21  24  64
# Arry     C  36  37  37  57
# Ack      A  57  60  18  84

# %%
# 在前10行内每两个取一个
df[0:10:2]
# Out:
#        team  Q1  Q2  Q3  Q4
# name
# Liver     E  89  21  24  64
# Ack       A  57  60  18  84
# Oah       D  65  49  61  86
# Acob      B  61  95  94   8
# Reddie    D  64  93  57  72

# %%
# 前10个
df.iloc[:10,:]
# Out:
#        team  Q1  Q2  Q3  Q4
# name
# Liver     E  89  21  24  64
# Arry      C  36  37  37  57
# Ack       A  57  60  18  84
# Eorge     C  93  96  71  78
# Oah       D  65  49  61  86
# Harlie    C  24  13  87  43
# Acob      B  61  95  94   8
# Lfie      A   9  10  99  37
# Reddie    D  64  93  57  72
# Oscar     A  77   9  26  67

# %%
# 指定行和列
df.loc['Ben', 'Q1':'Q4']
# Out:
# Q1    21
# Q2    43
# Q3    41
# Q4    74
# Name: Ben, dtype: object

# %%
# 指定行区间
df.loc['Eorge': 'Alexander', 'team': 'Q4']
# Out:
#           team  Q1  Q2  Q3  Q4
# name
# Eorge        C  93  96  71  78
# Oah          D  65  49  61  86
# Harlie       C  24  13  87  43
# Acob         B  61  95  94   8
# Lfie         A   9  10  99  37
# Reddie       D  64  93  57  72
# Oscar        A  77   9  26  67
# Leo          B  17   4  33  79
# Logan        B   9  89  35  65
# Archie       C  83  89  59  68
# Theo         C  51  86  87  27
# Thomas       B  80  48  56  41
# James        E  48  77  52  11
# Joshua       A  63   4  80  30
# Henry        A  91  15  75  17
# William      C  80  68   3  26
# Max          E  97  75  41   3
# Lucas        A  60  41  77  62
# Ethan        D  79  45  89  88
# Arthur       A  44  53  42  40
# Mason        D  80  96  26  49
# Isaac        E  74  23  28  65
# Harrison     B  89  13  18  75
# Teddy        E  71  91  21  48
# Finley       D  62  73  84  68
# Daniel       C  50  50  72  61
# Riley        E  35  26  59  83
# Edward       B  57  38  86  87
# Joseph       E  67  87  87  93
# ...

# %%
# 条件选择
df[df.Q1 > 90]
# Out:
#           team  Q1  Q2  Q3  Q4
# name
# Eorge        C  93  96  71  78
# Henry        A  91  15  75  17
# Max          E  97  75  41   3
# Alexander    C  91  76  26  79
# Elijah       B  97  89  15  46
# Ryan         E  92  70  64  31
# Aaron        A  96  75  55   8
# Lincoln4     C  98  93   1  20

# %%
df[df.index == 'Oscar']
# Out:
#       team  Q1  Q2  Q3  Q4
# name
# Oscar    A  77   9  26  67

# %%
# 组合条件
df[(df['Q1'] > 90) & (df['team'] == 'C')] # and 关系
df[df['team'] == 'C'].loc[df.Q1 > 90] # 多重选择
# df.loc[df.Q1 > 90]
# Out:
#           team  Q1  Q2  Q3  Q4
# name
# Eorge        C  93  96  71  78
# Henry        A  91  15  75  17
# Max          E  97  75  41   3
# Alexander    C  91  76  26  79
# Elijah       B  97  89  15  46
# Ryan         E  92  70  64  31
# Aaron        A  96  75  55   8
# Lincoln4     C  98  93   1  20

# %% [markdown]
# ### 排序

# %%
df.sort_values(by='Q1') # 按照 Q1 列 升序排列
df.sort_values(by='Q1', ascending=False) # 按照 Q1 列 降序排列
# Out:
#           team  Q1  Q2  Q3  Q4
# name
# Lincoln4     C  98  93   1  20
# Max          E  97  75  41   3
# Elijah       B  97  89  15  46
# Aaron        A  96  75  55   8
# Eorge        C  93  96  71  78
# ...        ...  ..  ..  ..  ..
# Lewis        B   4  34  77  28
# Finn         E   4   1  55  32
# Liam         B   2  80  24  25
# Harley       B   2  99  12  13
# Sebastian    C   1  14  68  48
#
# [100 rows x 5 columns]

# %%
df.sort_values(['team', 'Q1'], ascending=[True, False]) # 按照 team 升序 Q1 列 降序
# Out:
#          team  Q1  Q2  Q3  Q4
# name
# Aaron       A  96  75  55   8
# Henry       A  91  15  75  17
# Nathan      A  87  77  62  13
# Dylan       A  86  87  65  20
# Blake       A  78  23  93   9
# ...       ...  ..  ..  ..  ..
# Eli         E  11  74  58  91
# Jude        E   8  45  13  65
# Rory9       E   8  12  58  27
# Jackson5    E   6  10  15  33
# Finn        E   4   1  55  32
#
# [100 rows x 5 columns]

# %% [markdown]
# ### 分类聚合

# %%
df.groupby('team').sum()
# Out:
#         Q1    Q2    Q3    Q4
# team
# A     1066   639   875   783
# B      975  1218  1202  1136
# C     1056  1194  1068  1127
# D      860  1191  1241  1199
# E      963  1013   881  1033

# %%
df.groupby('team').mean()
# Out:
#              Q1         Q2         Q3         Q4
# team
# A     62.705882  37.588235  51.470588  46.058824
# B     44.318182  55.363636  54.636364  51.636364
# C     48.000000  54.272727  48.545455  51.227273
# D     45.263158  62.684211  65.315789  63.105263
# E     48.150000  50.650000  44.050000  51.650000

# %%
# 不同列不同聚合方式
df.groupby('team').agg({
    'Q1': sum, # 总和
    'Q2': 'count', # 总数
    'Q3': 'mean', # 平均
    'Q4': max # 最大值
})
# Out:
#         Q1  Q2         Q3  Q4
# team
# A     1066  17  51.470588  97
# B      975  22  54.636364  99
# C     1056  22  48.545455  98
# D      860  19  65.315789  99
# E      963  20  44.050000  98

# %% [markdown]
# ### 数据转换

# %%
# team 分组求和 行转列
df.groupby('team').sum().T
# Out:
# team     A     B     C     D     E
# Q1    1066   975  1056   860   963
# Q2     639  1218  1194  1191  1013
# Q3     875  1202  1068  1241   881
# Q4     783  1136  1127  1199  1033

# %%
df.groupby('team').sum().stack()
# Out:
# team
# A     Q1    1066
#       Q2     639
#       Q3     875
#       Q4     783
# B     Q1     975
#       Q2    1218
#       Q3    1202
#       Q4    1136
# C     Q1    1056
#       Q2    1194
#       Q3    1068
#       Q4    1127
# D     Q1     860
#       Q2    1191
#       Q3    1241
#       Q4    1199
# E     Q1     963
#       Q2    1013
#       Q3     881
#       Q4    1033
# dtype: int64

# %%
df.groupby('team').sum().unstack()
# Out:
#     team
# Q1  A       1066
#     B        975
#     C       1056
#     D        860
#     E        963
# Q2  A        639
#     B       1218
#     C       1194
#     D       1191
#     E       1013
# Q3  A        875
#     B       1202
#     C       1068
#     D       1241
#     E        881
# Q4  A        783
#     B       1136
#     C       1127
#     D       1199
#     E       1033
# dtype: int64

# %% [markdown]
# ### 增加列

# %%
df['one'] = 1 # 增加名叫 one 的固定列
df
# Out:
#          team  Q1  Q2  Q3  Q4  one
# name
# Liver       E  89  21  24  64    1
# Arry        C  36  37  37  57    1
# Ack         A  57  60  18  84    1
# Eorge       C  93  96  71  78    1
# Oah         D  65  49  61  86    1
# ...       ...  ..  ..  ..  ..  ...
# Gabriel     C  48  59  87  74    1
# Austin7     C  21  31  30  43    1
# Lincoln4    C  98  93   1  20    1
# Eli         E  11  74  58  91    1
# Ben         E  21  43  41  74    1
#
# [100 rows x 6 columns]

# %%
df['total'] = df.Q1 + df.Q2 + df.Q3 + df.Q4 # 增加总成绩列
df
# Out:
#          team  Q1  Q2  Q3  Q4  one  total
# name
# Liver       E  89  21  24  64    1    198
# Arry        C  36  37  37  57    1    167
# Ack         A  57  60  18  84    1    219
# Eorge       C  93  96  71  78    1    338
# Oah         D  65  49  61  86    1    261
# ...       ...  ..  ..  ..  ..  ...    ...
# Gabriel     C  48  59  87  74    1    268
# Austin7     C  21  31  30  43    1    125
# Lincoln4    C  98  93   1  20    1    212
# Eli         E  11  74  58  91    1    234
# Ben         E  21  43  41  74    1    179
#
# [100 rows x 7 columns]

# %%
df['total'] = df.loc[:, 'Q1':"Q4"].apply(lambda x:sum(x), axis=1)
df
# Out:
#          team  Q1  Q2  Q3  Q4  one  total
# name
# Liver       E  89  21  24  64    1    198
# Arry        C  36  37  37  57    1    167
# Ack         A  57  60  18  84    1    219
# Eorge       C  93  96  71  78    1    338
# Oah         D  65  49  61  86    1    261
# ...       ...  ..  ..  ..  ..  ...    ...
# Gabriel     C  48  59  87  74    1    268
# Austin7     C  21  31  30  43    1    125
# Lincoln4    C  98  93   1  20    1    212
# Eli         E  11  74  58  91    1    234
# Ben         E  21  43  41  74    1    179
#
# [100 rows x 7 columns]

# %%
df['total'] = df.sum(axis=1)
df
# Out:
# /tmp/ipykernel_14040/2156962985.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df['total'] = df.sum(axis=1)
#          team  Q1  Q2  Q3  Q4  one  total
# name
# Liver       E  89  21  24  64    1    596
# Arry        C  36  37  37  57    1    503
# Ack         A  57  60  18  84    1    659
# Eorge       C  93  96  71  78    1   1016
# Oah         D  65  49  61  86    1    785
# ...       ...  ..  ..  ..  ..  ...    ...
# Gabriel     C  48  59  87  74    1    806
# Austin7     C  21  31  30  43    1    377
# Lincoln4    C  98  93   1  20    1    638
# Eli         E  11  74  58  91    1    704
# Ben         E  21  43  41  74    1    539
#
# [100 rows x 7 columns]

# %%
# df['team_total'] = df.groupby('team').sum()
df2 = df[['team','total']].groupby('team').sum()
df2
# df['team_total'] = df2
# df['team_total'] = df[['team','total']].groupby('team').sum()
# df
# Out:
#       total
# team
# A     10123
# B     13637
# C     13379
# D     13511
# E     11710

# %%
df2[df2.index == 'A']
# Out:
#       total
# team
# A     10123

# %%
df3 = df.join(df2, on='team', lsuffix='_1', rsuffix='_2')
df3
# Out:
#          team  Q1  Q2  Q3  Q4  one  total_1  team_total  total_2
# name
# Liver       E  89  21  24  64    1      596         NaN    11710
# Arry        C  36  37  37  57    1      503         NaN    13379
# Ack         A  57  60  18  84    1      659         NaN    10123
# Eorge       C  93  96  71  78    1     1016         NaN    13379
# Oah         D  65  49  61  86    1      785         NaN    13511
# ...       ...  ..  ..  ..  ..  ...      ...         ...      ...
# Gabriel     C  48  59  87  74    1      806         NaN    13379
# Austin7     C  21  31  30  43    1      377         NaN    13379
# Lincoln4    C  98  93   1  20    1      638         NaN    13379
# Eli         E  11  74  58  91    1      704         NaN    11710
# Ben         E  21  43  41  74    1      539         NaN    11710
#
# [100 rows x 9 columns]

# %%
# df3['team_total'].drop
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [81], in <cell line: 1>()
# ----> 1 df3
#
# NameError: name 'df3' is not defined

# %% [markdown]
# ### 统计分析

# %%
df.loc[:,:].mean() # 返回所有列的均值
df.mean(1) # 返回所有行的均值
df.corr() # 返回列与列之间的相关系数
df.count() # 返回每一列中的非空值的个数
df.max() # 返回每一列的最大值
df.max(1) # 返回每一行的最大值
df.min() # 返回每一列的最小值
df.min(1) # 返回每一行的最小值
df.median() # 返回每一列的中位数
df.std() # 返回每一列的标准差
df.var() #方差
df.mode() # 众数
# Out:
# /tmp/ipykernel_14040/2420061065.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.loc[:,:].mean() # 返回所有列的均值
# /tmp/ipykernel_14040/2420061065.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean(1) # 返回所有行的均值
# /tmp/ipykernel_14040/2420061065.py:6: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.max(1) # 返回每一行的最大值
# ...

# %% [markdown]
# ### 绘图

# %%
df['Q1'].plot() # Q1 成绩的折线分布
# Out:
# <AxesSubplot:xlabel='name'>

# %%
df.loc['Ben', 'Q1':'Q4'].plot() # Ben 四个季度的成绩变化 折线图
# Out:
# <AxesSubplot:>

# %%
df.loc['Ben', 'Q1':'Q4'].plot.bar() # 柱状图
# Out:
# <AxesSubplot:>

# %%
df.loc['Ben', 'Q1':'Q4'].plot.barh() # 横向柱状图
# Out:
# <AxesSubplot:>

# %%
# 各个 team 4个季度 总成绩趋势
df.groupby('team').sum().T.plot()
# Out:
# <AxesSubplot:>

# %%
# 各组人数对比
df.groupby('team').count().Q1.plot.pie()
# Out:
# <AxesSubplot:ylabel='Q1'>

# %%
df['total'] = df.sum(axis=1)
df
# Out:
# /tmp/ipykernel_14040/2156962985.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df['total'] = df.sum(axis=1)
#         name team  Q1  Q2  Q3  Q4  total
# 0      Liver    E  89  21  24  64    396
# 1       Arry    C  36  37  37  57    334
# 2        Ack    A  57  60  18  84    438
# 3      Eorge    C  93  96  71  78    676
# 4        Oah    D  65  49  61  86    522
# ..       ...  ...  ..  ..  ..  ..    ...
# 95   Gabriel    C  48  59  87  74    536
# 96   Austin7    C  21  31  30  43    250
# 97  Lincoln4    C  98  93   1  20    424
# 98       Eli    E  11  74  58  91    468
# 99       Ben    E  21  43  41  74    358
#
# [100 rows x 7 columns]

# %% [markdown]
# ### 导出 excel

# %%
df.to_excel('team-done.xlsx') # 导出 excel 文件

# %%
df.to_csv('team-done.csv') # 导出 csv 文件
